# %%
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_excel("season-data.xlsx",engine='openpyxl', sheet_name="SAMPLE", index_col="data")

result = seasonal_decompose(
    
    df['actual'], 
    model='mul', 
    period=12,
    extrapolate_trend=True,
    two_sided=False
    
    )

df['trend'] = result.trend
df['seasonal'] = result.seasonal
df['resid'] = result.resid

df[['factor', 'seasonal']].plot(figsize=(12,6));

# %%
df[['factor', 'seasonal']]
# Out:
#               factor  seasonal
# data
# 2012-01-01  1.051978  1.059704
# 2012-02-01  1.075652  0.991313
# 2012-03-01  0.876282  0.882958
# 2012-04-01  0.902295  0.882579
# 2012-05-01  0.852489  0.886378
# ...              ...       ...
# 2022-10-01  0.997170  1.046154
# 2022-11-01  1.135872  1.132329
# 2022-12-01  1.367503  1.320442
# 2023-01-01  1.091111  1.059704
# 2023-02-01  1.056901  0.991313
#
# [134 rows x 2 columns]
